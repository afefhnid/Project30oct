# %% [markdown]
# # Credit card transaction dataset containing legitimate and fraud transactions from the duration 1st Jan 2019 - 31st Dec 2020 : Fraud

# %% [markdown]
# About the Dataset
# This is a simulated credit card transaction dataset containing legitimate and fraud transactions from the duration 1st Jan 2019 - 31st Dec 2020. It covers credit cards of 1000 customers doing transactions with a pool of 800 merchants.
#
# Source of Simulation
# This was generated using Sparkov Data Generation | Github tool created by Brandon Harris. This simulation was run for the duration - 1 Jan 2019 to 31 Dec 2020. The files were combined and converted into a standard format.
#
# Acknowledgements
# Brandon Harris for his amazing work in creating this easy-to-use simulation tool for creating fraud transaction datasets.

# %% [markdown]
# L'objectif de ce notebook est de nettoyer inteligemment ce datastet pour rendre intelligible tous les renseignements cachés dans celui ci et obtenir la meilleur performance du modele de ML associé

# %% [markdown]
# #### Inscris toi sur kaggle et download les fichiers de la competition sur le lien ci dessus

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
import datetime

# %% [markdown]
# # Chargement des jeux de données et préparation des train/test

# %% [markdown]
# #### Chargement du dataset de train et de test

# %%
train=pd.read_csv('fraudTrain.csv')
train
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                 0   2019-01-01 00:00:18     2703186189652095
# 1                 1   2019-01-01 00:00:44         630423337322
# 2                 2   2019-01-01 00:00:51       38859492057661
# 3                 3   2019-01-01 00:01:16     3534093764340240
# 4                 4   2019-01-01 00:03:06      375534208663984
# ...             ...                   ...                  ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# 2                       fraud_Lind-Buckridge  entertainment  220.11
# 3         fraud_Kutch, Hermiston and Farrell  gas_transport   45.00
# 4                        fraud_Keeling-Crist       misc_pos   41.96
# ...                                      ...            ...     ...
# 1296670                    fraud_Reichel Inc  entertainment   15.56
# 1296671             fraud_Abernathy and Sons    food_dining   51.70
# 1296672                 fraud_Stiedemann Ltd    food_dining  105.93
# 1296673  fraud_Reinger, Weissnat and Strosin    food_dining   74.90
# 1296674  fraud_Langosh, Wintheiser and Hyatt    food_dining    4.30
#
#                first       last gender                         street  ...  \
# 0           Jennifer      Banks      F                 561 Perry Cove  ...
# 1          Stephanie       Gill      F   43039 Riley Greens Suite 393  ...
# 2             Edward    Sanchez      M       594 White Dale Suite 530  ...
# 3             Jeremy      White      M    9443 Cynthia Court Apt. 038  ...
# 4              Tyler     Garcia      M               408 Bradley Rest  ...
# ...              ...        ...    ...                            ...  ...
# 1296670         Erik  Patterson      M       162 Jessica Row Apt. 072  ...
# 1296671      Jeffrey      White      M  8617 Holmes Terrace Suite 651  ...
# 1296672  Christopher  Castaneda      M     1632 Cohen Drive Suite 639  ...
# 1296673       Joseph     Murray      M           42933 Ryan Underpass  ...
# 1296674      Jeffrey      Smith      M           135 Joseph Mountains  ...
#
#              lat      long  city_pop                                job  \
# 0        36.0788  -81.1781      3495          Psychologist, counselling
# 1        48.8878 -118.2105       149  Special educational needs teacher
# 2        42.1808 -112.2620      4154        Nature conservation officer
# 3        46.2306 -112.1138      1939                    Patent attorney
# 4        38.4207  -79.4629        99     Dance movement psychotherapist
# ...          ...       ...       ...                                ...
# 1296670  37.7175 -112.4777       258                       Geoscientist
# 1296671  39.2667  -77.5101       100   Production assistant, television
# 1296672  32.9396 -105.8189       899                    Naval architect
# 1296673  43.3526 -102.5411      1126              Volunteer coordinator
# 1296674  45.8433 -113.8748       218           Therapist, horticultural
#
#                 dob                         trans_num   unix_time  merch_lat  \
# 0        1988-03-09  0b242abb623afc578575680df30655b9  1325376018  36.011293
# 1        1978-06-21  1f76529f8574734946361c461b024d99  1325376044  49.159047
# 2        1962-01-19  a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704
# 3        1967-01-12  6b849c168bdad6f867558c3793159a81  1325376076  47.034331
# 4        1986-03-28  a41d7549acf90789359a9aa5346dcb46  1325376186  38.674999
# ...             ...                               ...         ...        ...
# 1296670  1961-11-24  440b587732da4dc1a6395aba5fb41669  1371816728  36.841266
# 1296671  1979-12-11  278000d2e0d2277d1de2f890067dcc0a  1371816739  38.906881
# 1296672  1967-08-30  483f52fe67fabef353d552c1e662974c  1371816752  33.619513
# 1296673  1980-08-18  d667cdcbadaaed3da3f4020e83591c83  1371816816  42.788940
# 1296674  1995-08-16  8f7c8e4ab7f25875d753b422917c98c9  1371816817  46.565983
#
#          merch_long  is_fraud
# 0        -82.048315         0
# 1       -118.186462         0
# 2       -112.154481         0
# 3       -112.561071         0
# 4        -78.632459         0
# ...             ...       ...
# 1296670 -111.690765         0
# 1296671  -78.246528         0
# 1296672 -105.130529         0
# 1296673 -103.241160         0
# 1296674 -114.186110         0
#
# [1296675 rows x 23 columns]

# %%
train.sample(50)
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 305221       305221   2019-05-27 23:13:58          60427851591
# 598011       598011   2019-09-10 18:28:08     5596347693144598
# 1274422     1274422   2020-06-13 15:35:26     4836998673805450
# 1238448     1238448   2020-05-31 20:54:02         581508178315
# 1152720     1152720   2020-04-26 03:35:36      180048185037117
# 680252       680252   2019-10-17 09:50:51  4092452671396169678
# 1153612     1153612   2020-04-26 13:12:50  4089096483689733451
# 1141299     1141299   2020-04-20 16:16:31      344342339068828
# 620480       620480   2019-09-21 08:27:43        4640395708703
# 1008137     1008137   2020-02-18 13:22:37      377550167323848
# 864876       864876   2019-12-18 19:36:07     6011399591920186
# 175037       175037   2019-04-01 15:15:30     4653879239169997
# 383506       383506   2019-06-24 20:05:44  4390966588600992777
# 804736       804736   2019-12-05 15:53:15      180042946491150
# 1232295     1232295   2020-05-29 16:12:53      180064817343047
# 220328       220328   2019-04-21 20:34:29         630424987505
# 995074       995074   2020-02-10 19:08:52      180014262259255
# 296949       296949   2019-05-25 19:55:10     3560697798177746
# 68054         68054   2019-02-10 07:24:46        4586260469584
# 732273       732273   2019-11-09 12:18:05       38199021865320
# 23587         23587   2019-01-14 19:43:18     6011917798331152
# 258420       258420   2019-05-08 19:46:50      213120463918358
# 726007       726007   2019-11-06 04:38:54      344709867813900
# 743695       743695   2019-11-14 10:11:44     4922710831011201
# 1035025     1035025   2020-03-04 20:48:39        4683638447911
# 363717       363717   2019-06-17 19:00:24       30118423745458
# 597029       597029   2019-09-10 01:11:55     4658490815480264
# 1291548     1291548   2020-06-19 12:23:38  4587657402165341815
# 171339       171339   2019-03-31 11:28:42     2254799658404120
# 224160       224160   2019-04-23 03:12:04     3589289942931264
# 21323         21323   2019-01-13 20:08:17     4518350514020532
# 705448       705448   2019-10-28 02:11:42     4119762878330989
# 37209         37209   2019-01-22 14:19:09       30561214688470
# 711995       711995   2019-10-31 08:15:28     4149238353975790
# 448316       448316   2019-07-18 15:09:14      180046165512893
# 59164         59164   2019-02-04 18:05:55     6011693194885790
# 823466       823466   2019-12-09 08:35:14      342035762534413
# 910852       910852   2019-12-29 06:20:36        4809701904914
# 279692       279692   2019-05-18 15:21:16  4906628655840914250
# 700959       700959   2019-10-26 16:28:28     4951647200979051
# 448621       448621   2019-07-18 17:44:33     4328928491302401
# 34997         34997   2019-01-21 15:27:54     6011104316292105
# 1122431     1122431   2020-04-12 17:20:56        4585132874641
# 496495       496495   2019-08-04 12:55:03       30290551782700
# 448144       448144   2019-07-18 13:28:34     3589255887819806
# 1293561     1293561   2020-06-20 07:56:04          60416207185
# 71909         71909   2019-02-11 23:47:42     4836998673805450
# 1108741     1108741   2020-04-06 12:28:08     4134456652433447
# 305198       305198   2019-05-27 23:08:04  4089096483689733451
# 150298       150298   2019-03-22 09:25:21     6011477612335392
#
#                                             merchant        category     amt  \
# 305221           fraud_Effertz, Welch and Schowalter   entertainment   72.50
# 598011                            fraud_Prosacco LLC   personal_care   26.34
# 1274422                fraud_Weber, Thiel and Hammes       kids_pets   14.13
# 1238448                       fraud_O'Hara-Wilderman     food_dining   75.38
# 1152720                              fraud_Kunze Inc     grocery_pos  188.59
# 680252                             fraud_Kilback LLC     grocery_pos  128.71
# 1153612             fraud_Okuneva, Schneider and Rau    shopping_pos   95.07
# 1141299        fraud_Bahringer, Bergnaum and Quitzon            home   45.01
# 620480                               fraud_Price Inc    shopping_net    3.08
# 1008137                       fraud_Pacocha-Weissnat       kids_pets   65.19
# 864876                           fraud_Abbott-Rogahn   entertainment  133.68
# 175037                fraud_Lesch, D'Amore and Brown     food_dining    1.23
# 383506             fraud_Romaguera, Wehner and Tromp       kids_pets  174.60
# 804736                             fraud_Yost-Rogahn   personal_care    8.09
# 1232295                            fraud_Effertz LLC   entertainment    6.50
# 220328                             fraud_Streich Ltd            home   30.65
# 995074                          fraud_Hoppe-Parisian       kids_pets  117.20
# 296949                        fraud_Kautzer and Sons   personal_care  109.27
# 68054                   fraud_Zieme, Bode and Dooley   gas_transport   76.70
# 732273              fraud_Zemlak, Tillman and Cremin   personal_care   70.98
# 23587                              fraud_Watsica LLC   personal_care   59.04
# 258420             fraud_Hills, Hegmann and Schaefer  health_fitness  106.48
# 726007           fraud_Johnston, Nikolaus and Maggio     grocery_net   39.31
# 743695           fraud_Harris, Gusikowski and Heaney     grocery_net   82.78
# 1035025                fraud_Lang, Towne and Schuppe       kids_pets   40.80
# 363717                           fraud_Jast and Sons     food_dining    6.65
# 597029                      fraud_Spencer-Runolfsson        misc_pos    4.51
# 1291548                        fraud_Jacobi and Sons    shopping_pos  200.54
# 171339                               fraud_Kunze Inc     grocery_pos  257.27
# 224160              fraud_Schumm, Bauch and Ondricka     grocery_pos  109.22
# 21323                           fraud_O'Keefe-Wisoky     food_dining   72.23
# 705448                            fraud_Bins-Tillman   entertainment   27.91
# 37209         fraud_Stanton, Jakubowski and Baumbach    shopping_net    1.24
# 711995            fraud_Quitzon, Green and Bashirian    shopping_pos  119.16
# 448316                              fraud_Kuhn Group     food_dining   70.98
# 59164                             fraud_Schulist Ltd     food_dining   18.96
# 823466                              fraud_Harris Inc   gas_transport   55.36
# 910852                         fraud_Cummerata-Jones   gas_transport   45.85
# 279692                          fraud_Jast-McDermott    shopping_pos   28.91
# 700959                             fraud_Cormier LLC  health_fitness   10.74
# 448621                          fraud_Sporer-Keebler   personal_care   31.70
# 34997           fraud_Langworth, Boehm and Gulgowski    shopping_net    4.29
# 1122431                              fraud_Kuhic LLC    shopping_net    2.36
# 496495                         fraud_Connelly-Carter            home   86.54
# 448144                        fraud_Bogisich-Weimann       kids_pets   58.96
# 1293561                       fraud_Rutherford-Mertz     grocery_pos   64.78
# 71909                        fraud_O'Connell-Ullrich            home   23.91
# 1108741                       fraud_Corwin-Romaguera          travel    1.35
# 305198                                fraud_Jast Ltd    shopping_net   28.70
# 150298   fraud_Christiansen, Goyette and Schamberger   gas_transport   41.52
#
#                first       last gender                         street  ...  \
# 305221       Bradley   Martinez      M    3426 David Divide Suite 717  ...
# 598011        Joseph      Moody      M               5901 Foster Pine  ...
# 1274422        Susan      Hardy      F                516 Brown Parks  ...
# 1238448      Michael     Vargas      M              933 Martin Rapids  ...
# 1152720         Mary       Wall      F                2481 Mills Lock  ...
# 680252       Jeffrey     Vargas      M           478 Alexandria Mount  ...
# 1153612        Debra      Stark      F                 686 Linda Rest  ...
# 1141299         Ruth     Fuller      F      37732 Joe Courts Apt. 752  ...
# 620480       Melissa     Krause      F           67632 Martin Gateway  ...
# 1008137        Kevin    Walters      M              87227 Tapia Burgs  ...
# 864876         Maria        Roy      F  58665 Nicholas Ford Suite 348  ...
# 175037        Monica     Tucker      F          302 Christina Islands  ...
# 383506          Kyle    Simmons      M             8149 Harris Divide  ...
# 804736       Charles     Robles      M               3337 Lisa Divide  ...
# 1232295     Patricia   Gonzalez      F                8973 Mark Drive  ...
# 220328      Jennifer      Black      F     2870 Bean Terrace Apt. 756  ...
# 995074       Brianna       Page      F               0043 Henry Plaza  ...
# 296949       Matthew      Young      M     8840 Miller Port Suite 645  ...
# 68054         Melody   Thompson      F             0362 Anderson Wall  ...
# 732273         Jesse    Roberts      M   8415 Vaughn Squares Apt. 788  ...
# 23587        William    Johnson      M          50843 Vincent Mission  ...
# 258420        Willie     Jordan      M                   529 West Key  ...
# 726007        Joanna     Hudson      F          2924 Bobby Trafficway  ...
# 743695       Heather      Chase      F    6888 Hicks Stream Suite 954  ...
# 1035025       Daniel       Boyd      M           8925 Nicholas Points  ...
# 363717         Jared  Velazquez      M            01479 Murray Circle  ...
# 597029          Tara   Richards      F          4879 Cristina Station  ...
# 1291548        Amber      Lewis      F       6296 John Keys Suite 858  ...
# 171339       Barbara     Nelson      F  7337 Browning Falls Suite 027  ...
# 224160         Paula    Estrada      F                350 Stacy Glens  ...
# 21323    Christopher    Gregory      M             9579 Porter Tunnel  ...
# 705448       Melinda  Gutierrez      F              1497 West Gateway  ...
# 37209           Gina   Morrison      F  41851 Victor Drives Suite 219  ...
# 711995        Tanner    Carroll      M                494 Burke Ports  ...
# 448316         Erica     Walker      F    084 Holmes Avenue Suite 206  ...
# 59164       Victoria    Fleming      F  2807 Parker Station Suite 080  ...
# 823466      Jennifer   Carrillo      F    334 Adam Mountains Apt. 868  ...
# 910852       Sabrina      Nolan      F   312 Eric Expressway Apt. 014  ...
# 279692       Charles     Moreno      M  838 Franklin Prairie Apt. 902  ...
# 700959      Kimberly     Miller      F           75533 Tamara Valleys  ...
# 448621      Margaret        Ray      F   927 Cummings Manor Suite 318  ...
# 34997        Valerie      Davis      F    3861 Anderson Ramp Apt. 536  ...
# 1122431        Karen     Gordon      F         543 Ware Path Apt. 593  ...
# 496495          John     Clarke      M           27909 Peter Motorway  ...
# 448144         David     Miller      M     622 Bradley Knoll Apt. 758  ...
# 1293561         Mary       Diaz      F               9886 Anita Drive  ...
# 71909          Susan      Hardy      F                516 Brown Parks  ...
# 1108741     Lawrence      Ellis      M      1471 Alicia Flat Apt. 993  ...
# 305198         Debra      Stark      F                 686 Linda Rest  ...
# 150298       Anthony    Roberts      M             95488 Cabrera Well  ...
#
#              lat      long  city_pop                                      job  \
# 305221   35.3492  -99.1880      2142                   Politician's assistant
# 598011   29.9912  -90.2479     68211                      Engineer, petroleum
# 1274422  46.0062  -86.2555      6469                      Trade mark attorney
# 1238448  32.2819  -98.5673       407            Clothing/textile technologist
# 1152720  40.6152  -74.4150     71485                   Leisure centre manager
# 680252   34.3091  -78.3372      2290                     Engineer, biomedical
# 1153612  32.3836  -94.8653     24536                    Multimedia programmer
# 1141299  31.3826  -81.4312      5989                              Tax adviser
# 620480   30.6576  -91.6264      1178              Community education officer
# 1008137  44.0948  -70.2390     23045       Tourist information centre manager
# 864876   42.1001  -73.3611      2121                           Radio producer
# 175037   37.0581  -86.1938      6841                        Therapist, sports
# 383506   35.6174  -97.5583    640470                   Advertising copywriter
# 804736   27.7898  -82.7243    341043                           Engineer, land
# 1232295  37.9048  -86.5240       344      Chartered public finance accountant
# 220328   39.1505  -79.5030       836                    Forensic psychologist
# 995074   31.5710  -86.2743      2566                    Exercise physiologist
# 296949   33.7163 -116.3381      4677                          Learning mentor
# 68054    40.1362  -95.2138      1631                                Architect
# 732273   43.1960  -72.3001       477                          Naval architect
# 23587    43.1699  -72.8515       828         Scientific laboratory technician
# 258420   32.9550  -92.5870      1758                   Psychologist, forensic
# 726007   27.4703  -81.4872     50835                 Environmental consultant
# 743695   40.3359  -79.6607      1472                Public affairs consultant
# 1035025  30.2510  -92.5002      1261                      Broadcast presenter
# 363717   40.4109  -74.2380     30770                        Drilling engineer
# 597029   39.9636  -79.7853       184                        Systems developer
# 1291548  41.0646  -87.5917      2135                   Psychotherapist, child
# 171339   30.9460  -83.2474     94325                 Educational psychologist
# 224160   43.7557  -97.5936       343    Development worker, international aid
# 21323    27.5517  -81.8074     14742           Teaching laboratory technician
# 705448   40.7152  -89.2706      6713                                Archivist
# 37209    40.5891  -75.4645    166081              Scientist, research (maths)
# 711995   40.1008  -80.0652       632                                   Dealer
# 448316   44.8021 -122.7624      9587                     Engineer, biomedical
# 59164    45.6675  -93.2433      2607              Lecturer, further education
# 823466   37.7184  -77.1860       976                     Engineer, automotive
# 910852   32.4204  -85.0796     59744                        Chemical engineer
# 279692   24.6557  -81.3824     32891                             Town planner
# 700959   37.9943  -88.9417       324  Scientist, research (physical sciences)
# 448621   42.9373  -87.9943     13973       Logistics and distribution manager
# 34997    36.9688  -78.5615      1970                          Energy engineer
# 1122431  39.7417  -93.6289       271                  Land/geomatics surveyor
# 496495   36.8020  -87.8286     13422                     Commissioning editor
# 448144   39.6991  -78.1762      3766                       Press photographer
# 1293561  43.0048 -108.8964      1645              Information systems manager
# 71909    46.0062  -86.2555      6469                      Trade mark attorney
# 1108741  40.6645  -73.7559     38912                       Production manager
# 305198   32.3836  -94.8653     24536                    Multimedia programmer
# 150298   40.4062  -84.5076      2274            Designer, television/film set
#
#                 dob                         trans_num   unix_time  merch_lat  \
# 305221   1976-06-30  c360fa6919dc6913abe0ce65c6737410  1338160438  36.254802
# 598011   1941-04-23  46d9404544df1023ca87e4a5cbd3b10b  1347301688  30.102386
# 1274422  1979-04-12  f546ffa494abaeecf9e51fab410da43c  1371137726  46.317526
# 1238448  1978-08-08  a924b416cf43aeb5bdedf0a422ee026d  1370033642  31.478242
# 1152720  1974-07-19  b2c4e80185aabd71aab17dd50b4bb77a  1366947336  40.219894
# 680252   1945-12-07  f01669c3068ae8859bb5e2d1de3d58f8  1350467451  33.470701
# 1153612  1983-10-14  cfa5082ea920559e80d86371a5e92109  1366981970  32.592770
# 1141299  1967-05-05  bb5e2188e12761e9fc8352350744d17a  1366474591  32.114457
# 620480   1951-06-13  32d33f6f22dc16c4e9240f594b3acf13  1348216063  29.695116
# 1008137  1958-09-02  cebdf1779f7c2ad03d721cf55c51caf9  1361193757  44.652758
# 864876   1973-10-14  d7c45acecce169754270cc5e67ad3ee0  1355859367  41.936042
# 175037   1999-06-06  351dd9a25e1b229b2be0b3e5bcb438a8  1333293330  38.023619
# 383506   1966-06-24  41fa5bf3762e39426f5087aaed9142ee  1340568344  35.791151
# 804736   1989-02-28  e4eec372ba9d34cda871bc8ffe2f51e0  1354722795  27.683687
# 1232295  1967-03-30  334a60028b66e57294409d3da9917f2c  1369843973  37.268372
# 220328   1981-08-29  c1d5db6dd915d61125efcc64a055db0c  1335040469  39.150645
# 995074   1958-06-26  aab7c4ee1b608c02cb5c0ac5b76a0dd3  1360523332  32.257580
# 296949   1955-05-06  bdbb2645297e71525302226374255db2  1337975710  32.952293
# 68054    1953-01-20  49981c68cb279d10f5316d10bed8ec62  1328858686  40.262194
# 732273   1988-04-15  c0940305f490d63117def47edbdb1882  1352463485  44.192884
# 23587    1957-08-30  0239a95f2a31d7220574e6a0ce99a2f1  1326570198  43.703675
# 258420   1957-08-08  e5a3ca62b3c0ede304ad18e2bb49cf37  1336506410  32.567384
# 726007   1986-01-30  71302dfeb43744b7c5213c690cb1eed5  1352176734  28.178964
# 743695   1941-03-07  386692a238723403f9539d7ae19d4db1  1352887904  41.075796
# 1035025  1972-07-01  9b67788e922bc370ee2b9aa625e9152a  1362430119  30.440965
# 363717   1993-04-29  02c5d0fb1c08461443dbd04aca33275f  1339959624  40.821404
# 597029   1945-11-04  ef9ba09993a235be605a808589e85729  1347239515  40.608953
# 1291548  2004-05-08  d01a3e4fbbb5e0b887dc7c846ca1cd0f  1371644618  41.940648
# 171339   1987-09-08  f18a277342bf2ba3d48c65d3f3b907d9  1333193322  30.320731
# 224160   1972-03-05  0fac2af1faba18a8f00e427ef95ba300  1335150724  43.957741
# 21323    1993-02-26  bcbc6e9857d4d57d83d55bffbda6ce5e  1326485297  27.142805
# 705448   1945-08-19  5923ac8d34e63d3b32b16697e8cce187  1351390302  40.555285
# 37209    1998-10-01  de168ab103a6c5135006161ea6eabcc2  1327241949  40.196417
# 711995   1989-04-08  3f9ec33529cba4a6a281f7bc0e6316ac  1351671328  39.927601
# 448316   1968-03-24  1abe8263faaa36bdd9dbc4e07e41d38b  1342624154  45.236304
# 59164    1995-12-04  9f6ac18cfc021f41a192d8e97c38acf5  1328378755  45.594938
# 823466   1999-06-19  1fa8b8bb1f14d34ea056a3e2bab3e283  1355042114  37.858336
# 910852   1984-02-07  d971bfdbaf944bf96a47b65d01485362  1356762036  31.828855
# 279692   1987-02-13  4377ae9881b4a0c9600e0760fb0ee874  1337354476  25.295804
# 700959   1976-06-15  72a3220049ded5d13f9a74f8a4b38d10  1351268908  37.376654
# 448621   1981-05-06  bc362daf71cc686e6fe4e983e85c0db3  1342633473  42.206317
# 34997    1985-09-02  795f76b3bb1d74cecb35a922457a7e9d  1327159674  37.664750
# 1122431  1972-04-18  15b3cf31b28f0ca037d563154a716ba5  1365787256  39.663234
# 496495   1961-09-03  2e6d30f52f186941edfa6c6ebe0354db  1344084903  36.394063
# 448144   1984-02-14  f9a8904d907ce41c69057b3ce686454c  1342618114  38.835709
# 1293561  1986-02-17  724b502a7bd0c5cd4c3b806dce7365c1  1371714964  43.916787
# 71909    1979-04-12  4300e339fcea21dfa70b45446feb05e0  1329004062  45.993068
# 1108741  1961-11-07  744c8b27a705b6a57128205ad71535ab  1365251288  40.130886
# 305198   1983-10-14  1f88c06880de8524c6348f7d6b085836  1338160084  31.837583
# 150298   1943-12-17  fdf807073b2d65fdf5b6148575855d30  1332408321  40.351930
#
#          merch_long  is_fraud
# 305221   -99.601044         0
# 598011   -89.817523         0
# 1274422  -85.927829         0
# 1238448  -98.799453         0
# 1152720  -74.793650         0
# 680252   -78.767812         0
# 1153612  -94.211151         0
# 1141299  -80.445382         0
# 620480   -91.217406         0
# 1008137  -70.663181         0
# 864876   -74.254019         0
# 175037   -86.979420         0
# 383506   -98.209936         0
# 804736   -82.730021         0
# 1232295  -85.995349         0
# 220328   -80.005986         0
# 995074   -85.331679         0
# 296949  -117.070874         0
# 68054    -94.360507         0
# 732273   -72.265494         0
# 23587    -72.891494         0
# 258420   -92.680816         0
# 726007   -82.156500         0
# 743695   -79.010711         0
# 1035025  -92.789863         0
# 363717   -73.536868         0
# 597029   -80.726749         0
# 1291548  -87.059250         0
# 171339   -82.801511         0
# 224160   -98.334203         0
# 21323    -82.612370         0
# 705448   -88.352597         0
# 37209    -75.241329         0
# 711995   -79.786859         0
# 448316  -122.711345         0
# 59164    -93.080059         0
# 823466   -76.638294         0
# 910852   -85.013414         0
# 279692   -82.259500         0
# 700959   -89.069575         0
# 448621   -87.124651         0
# 34997    -79.557045         0
# 1122431  -94.054321         0
# 496495   -86.831597         0
# 448144   -78.990146         0
# 1293561 -109.780848         0
# 71909    -86.634793         0
# 1108741  -72.866847         0
# 305198   -94.833045         0
# 150298   -84.333682         0
#
# [50 rows x 23 columns]

# %% [markdown]
# Verifier les doublan des transaction

# %%
print (len(train),len(train.drop_duplicates('trans_num')))
# Out:
# 1296675 1296675

# %% [markdown]
# Eleminer les Nan

# %%
train.dropna(inplace=True)

# %%
train['is_fraud'].value_counts()
# Out:
# 0    1289169
# 1       7506
# Name: is_fraud, dtype: int64

# %%
train['gender'].value_counts()
# Out:
# F    709863
# M    586812
# Name: gender, dtype: int64

# %% [markdown]
# Equilibrer la data

# %%
train_0 = train[train["is_fraud"] == 0].sample(7506)
train_1 = train[train["is_fraud"] == 1].sample(7506)
train=train_0.merge(train_1, how='outer')
train['is_fraud'].value_counts()
# Out:
# 1    7506
# 0    7506
# Name: is_fraud, dtype: int64

# %% [markdown]
# Et en pourcentage ?

# %%
train['is_fraud'].value_counts()*100/len(train)
# Out:
# 1    50.0
# 0    50.0
# Name: is_fraud, dtype: float64

# %% [markdown]
# # Analyse du dataset

# %%
train.describe(include="all")
# Out:
#           Unnamed: 0 trans_date_trans_time        cc_num            merchant  \
# count   1.501200e+04                 15012  1.501200e+04               15012
# unique           NaN                 15003           NaN                 693
# top              NaN   2020-06-08 22:41:15           NaN  fraud_Rau and Sons
# freq             NaN                     2           NaN                  71
# mean    6.339034e+05                   NaN  4.207137e+17                 NaN
# std     3.875771e+05                   NaN  1.310264e+18                 NaN
# min     3.550000e+02                   NaN  6.041621e+10                 NaN
# 25%     2.806985e+05                   NaN  1.800462e+14                 NaN
# 50%     6.412345e+05                   NaN  3.525591e+15                 NaN
# 75%     9.769340e+05                   NaN  4.651007e+15                 NaN
# max     1.296590e+06                   NaN  4.992346e+18                 NaN
#
#            category           amt        first   last gender  \
# count         15012  15012.000000        15012  15012  15012
# unique           14           NaN          352    481      2
# top     grocery_pos           NaN  Christopher  Smith      F
# freq           2459           NaN          304    335   7871
# mean            NaN    300.186292          NaN    NaN    NaN
# std             NaN    376.330398          NaN    NaN    NaN
# min             NaN      1.000000          NaN    NaN    NaN
# 25%             NaN     20.247500          NaN    NaN    NaN
# 50%             NaN     90.035000          NaN    NaN    NaN
# 75%             NaN    483.060000          NaN    NaN    NaN
# max             NaN   6756.430000          NaN    NaN    NaN
#
#                      street  ...           lat          long      city_pop  \
# count                 15012  ...  15012.000000  15012.000000  1.501200e+04
# unique                  980  ...           NaN           NaN           NaN
# top     40624 Rebecca Spurs  ...           NaN           NaN           NaN
# freq                     37  ...           NaN           NaN           NaN
# mean                    NaN  ...     38.630025    -90.145499  9.205207e+04
# std                     NaN  ...      5.121962     14.002393  3.121263e+05
# min                     NaN  ...     20.027100   -165.672300  2.300000e+01
# 25%                     NaN  ...     34.883800    -96.790900  7.410000e+02
# 50%                     NaN  ...     39.412500    -87.304600  2.456000e+03
# 75%                     NaN  ...     42.074000    -80.065200  2.112500e+04
# max                     NaN  ...     66.693300    -67.950300  2.906700e+06
#
#                        job         dob                         trans_num  \
# count                15012       15012                             15012
# unique                 494         965                             15012
# top     Materials engineer  1981-08-29  f7658c12f62ee6c5ae0dd50a06e315a7
# freq                   118          45                                 1
# mean                   NaN         NaN                               NaN
# std                    NaN         NaN                               NaN
# min                    NaN         NaN                               NaN
# 25%                    NaN         NaN                               NaN
# 50%                    NaN         NaN                               NaN
# 75%                    NaN         NaN                               NaN
# max                    NaN         NaN                               NaN
#
#            unix_time     merch_lat    merch_long      is_fraud
# count   1.501200e+04  15012.000000  15012.000000  15012.000000
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean    1.348724e+09     38.622363    -90.139432      0.500000
# std     1.333444e+07      5.166143     14.018675      0.500017
# min     1.325393e+09     19.138122   -166.550779      0.000000
# 25%     1.337381e+09     34.949127    -96.842433      0.000000
# 50%     1.348957e+09     39.420962    -87.287690      0.500000
# 75%     1.359671e+09     42.040956    -80.076790      1.000000
# max     1.371814e+09     67.510267    -67.132320      1.000000
#
# [11 rows x 23 columns]

# %% [markdown]
# Quelles variables sont correllees avec la Fraud carte?

# %% [markdown]
# # Colonnes cc_num

# %% [markdown]
# Ajouter une colonne numCardLength = la longeur de numéro de carte

# %%
train['numCardLength'] = train['cc_num'].astype(str).map(len)

# %%
sns.set_style('whitegrid')
tips = sns.load_dataset("tips")
ax = sns.barplot(x="numCardLength", y="is_fraud", data=train)
pyplot.gcf().set_size_inches(20, 10)

# %% [markdown]
# ===> D'aprés le graph on pourra remarquer que plus la longeur de numero de card est court plus le pourcentage de fraud est élevé

# %% [markdown]
# # Colonnes dob ==> Age

# %% [markdown]
# Ajoute une colonne Age apartir de la date de naissance

# %%
now = pd.Timestamp('now')
train['dob'] = pd.to_datetime(train['dob'], format='%Y-%m-%d') 
train['dob'] = train['dob'].where(train['dob'] < now, train['dob'] -  np.timedelta64(100, 'Y'))   
train['age'] = (now - train['dob']).astype('<m8[Y]')

# %%
train['age']
# Out:
# 0        74.0
# 1        50.0
# 2        30.0
# 3        37.0
# 4        25.0
#          ...
# 15007    47.0
# 15008    53.0
# 15009    30.0
# 15010    85.0
# 15011    89.0
# Name: age, Length: 15012, dtype: float64

# %%
train.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# numCardLength            0
# age                      0
# dtype: int64

# %%
train.isna().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# numCardLength            0
# age                      0
# dtype: int64

# %% [markdown]
# Voire la relation entre Age et le fraud

# %%
sns.set_style('whitegrid')
tips = sns.load_dataset("tips")
ax = sns.barplot(x="age", y="is_fraud", data=train)
pyplot.gcf().set_size_inches(10, 10)

# %%
sns.set_style('whitegrid')
tips = sns.load_dataset("tips")
ax = sns.barplot(x="age", y="is_fraud", data=train.sample(50))
pyplot.gcf().set_size_inches(20, 10)

# %% [markdown]
# # Colonnes category

# %%
sns.set_style('whitegrid')
tips = sns.load_dataset("tips")
ax = sns.barplot(x="category", y="is_fraud", data=train)
pyplot.gcf().set_size_inches(20, 10)

# %%
train['category']=train['category'].map({'gas_transport':0,"travel":1,'health_fitness':2,'misc_net':3,'home.':4,'kids_pets':5,'shopping_pos':6,'entertainment':7,'grocery_pos':8,'food_dining':9,'personal_care':10,'travel':11,'shopping_net':12,'misc_pos':13})

# %%
sns.set_style('whitegrid')
tips = sns.load_dataset("tips")
ax = sns.barplot(x="category", y="is_fraud", data=train)
pyplot.gcf().set_size_inches(20, 10)

# %% [markdown]
# les achates en ligne est la catégorie la plus élvé de fraud

# %% [markdown]
# # Colonnes city Pop

# %%
sns.set_style('whitegrid')
tips = sns.load_dataset("tips")
ax = sns.barplot(x="city_pop", y="is_fraud", data=train.sample(50))
pyplot.gcf().set_size_inches(20, 10)

# %% [markdown]
# # Colonnes city

# %%
train['city'].value_counts()
# Out:
# Warren          70
# Houston         62
# San Antonio     58
# Naples          57
# Huntsville      54
#                 ..
# Akron            1
# Jackson          1
# Pewee Valley     1
# Chatham          1
# Whittemore       1
# Name: city, Length: 891, dtype: int64

# %% [markdown]
# # Colonnes state

# %%
sns.set_style('whitegrid')
tips = sns.load_dataset("tips")
ax = sns.barplot(x="state", y="is_fraud", data=train.sample(50))
pyplot.gcf().set_size_inches(20, 10)

# %%
train['state'].value_counts()
# Out:
# NY    1048
# TX    1034
# PA     912
# CA     649
# OH     586
# FL     526
# MI     496
# IL     495
# AL     446
# MO     412
# MN     395
# SC     359
# VA     354
# AR     348
# WI     344
# NC     325
# MD     309
# IN     307
# NE     304
# GA     302
# KY     297
# OK     295
# IA     294
# KS     293
# WV     286
# OR     280
# NJ     257
# TN     238
# MS     234
# WY     226
# LA     216
# ME     215
# WA     206
# CO     205
# NM     179
# SD     158
# MA     153
# ND     150
# VT     143
# UT     119
# MT     106
# NH      99
# AZ      95
# NV      84
# CT      61
# ID      48
# AK      44
# DC      35
# RI      18
# HI      18
# DE       9
# Name: state, dtype: int64

# %%
train['state']=train['state'].map({"NY":0,"TX":1,"AL":2,"FL":3,"IL.":4,"MO":5,"PA":6,"VA":7,"NM":8,"SC":9,"IN":10,"MI":11,"NC":12,"OH":13,"MN":14,"KS":15,"OR":16,"TN":17,"LA.":18,"NH":19,"IA":20,"WI":21,"CA":22,"NE":23,"MT":24,"ND":25,"WA":26,"VT":27,"MA":28,"KY":29,"UT":30,"ID":31,"DC.":32,"AR":33,"WY":34,"OK":35,"NV":36,"GA":37,"CT":38,"MS":39,"MD":40,"NJ":41})

# %%
train['state']
# Out:
# 0        22.0
# 1         1.0
# 2        25.0
# 3        12.0
# 4         1.0
#          ...
# 15007     1.0
# 15008    29.0
# 15009    20.0
# 15010    23.0
# 15011     0.0
# Name: state, Length: 15012, dtype: float64

# %% [markdown]
# D'apres les information qu'on a on pourra pas predir le fraud par rapport à la popullation

# %% [markdown]
# # Colonnes gebder = M/F

# %% [markdown]
# Comparer entre les fraud de femme et celui de le homme

# %%
sns.set_style('whitegrid')
tips = sns.load_dataset("tips")
ax = sns.barplot(x="gender", y="is_fraud", data=train)
pyplot.gcf().set_size_inches(10, 10)

# %%
train['gender'].value_counts()
# Out:
# F    7871
# M    7141
# Name: gender, dtype: int64

# %% [markdown]
# Le nombre des femme est superieur à celui de femme mais les hommes sont les plus frauder

# %% [markdown]
# le nombre de fraude chez les hommes et légerment superieur que celui de femmes

# %% [markdown]
# ici on va voire la relation entre le fraud et la catégorie (lieu ou types de fraud )

# %%
train.isna().sum()
# Out:
# Unnamed: 0                  0
# trans_date_trans_time       0
# cc_num                      0
# merchant                    0
# category                 1302
# amt                         0
# first                       0
# last                        0
# gender                      0
# street                      0
# city                        0
# state                    1794
# zip                         0
# lat                         0
# long                        0
# city_pop                    0
# job                         0
# dob                         0
# trans_num                   0
# unix_time                   0
# merch_lat                   0
# merch_long                  0
# is_fraud                    0
# numCardLength               0
# age                         0
# dtype: int64

# %% [markdown]
# # Nettoiage des colonnes

# %%
train.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud', 'numCardLength', 'age'],
#       dtype='object')

# %%
train.rename(columns=lambda x: x.replace('Unnamed: 0', 'id'), inplace=True)

# %%
train.drop(['trans_date_trans_time'], axis='columns', inplace=True)
train.drop(['cc_num'], axis='columns', inplace=True)
train.drop(['merchant'], axis='columns', inplace=True)
train.drop(['category'], axis='columns', inplace=True)
train.drop(['long'], axis='columns', inplace=True)
train.drop(['job'], axis='columns', inplace=True)
train.drop(['unix_time'], axis='columns', inplace=True)
train.drop(['merch_lat'], axis='columns', inplace=True)
train.drop(['merch_long'], axis='columns', inplace=True)
train.drop(['street'], axis='columns', inplace=True)
train.drop(['first'], axis='columns', inplace=True)
train.drop(['last'], axis='columns', inplace=True)
train.drop(['city'], axis='columns', inplace=True)
train.drop(['zip'], axis='columns', inplace=True)
train.drop(['lat'], axis='columns', inplace=True)
train.drop(['dob'], axis='columns', inplace=True)
train.drop(['id'], axis='columns', inplace=True)
train.drop(['trans_num'], axis='columns', inplace=True)

# %%
train
# Out:
#            amt gender  state  city_pop  is_fraud  numCardLength   age
# 0        38.28      M   22.0       589         0             16  74.0
# 1        39.90      F    1.0     46563         0             16  50.0
# 2         6.82      F   25.0        77         0             16  30.0
# 3        99.42      F   12.0    186140         0             16  37.0
# 4         9.12      F    1.0     34153         0             14  25.0
# ...        ...    ...    ...       ...       ...            ...   ...
# 15007  1170.12      M    1.0    749635         1             16  47.0
# 15008   725.76      M   29.0       301         1             16  53.0
# 15009   221.76      F   20.0       533         1             16  30.0
# 15010   839.35      F   23.0        73         1             16  85.0
# 15011   301.36      M    0.0       397         1             15  89.0
#
# [15012 rows x 7 columns]

# %%
train['gender']=train['gender'].map({'M':0,"F":1})
train['gender']
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 15007    0
# 15008    0
# 15009    1
# 15010    1
# 15011    0
# Name: gender, Length: 15012, dtype: int64

# %% [markdown]
# #### J'aimerais recuperer les Nan(s) de la colonne backers_count (20%)

# %% [markdown]
# # Modélisation / Prédiction

# %% [markdown]
# #### Piocher dans la librairie sklearn des modeles de classification (RandomForest, Gradient Boost, LogisticRegression, ...) et realiser plusieurs modeles. Evaluer leur performance via accuracy_score()

# %%
train =train[~train.isin([np.nan, np.inf, -np.inf]).any(1)]

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier

from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split




X=train[['amt','gender','state','city_pop','numCardLength','age','is_fraud']].dropna(subset=['numCardLength'])
y=X['is_fraud'].copy()
del X['is_fraud']
x_train, x_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state = 0)
#reg = LinearRegression(normalize=True,fit_intercept=True).fit(X, y)
cls = RandomForestClassifier(max_depth=14,n_estimators=300, random_state=0).fit(x_train, y_train) #80%
cls.score(x_val, y_val) #%20
# Out:
# 0.9073373676248109

# %% [markdown]
# Bon, c'est pas terrible comme accuracy 86,94% mais on va commencer comme cela .Je sauve mon modèle (reg) en format pickle (.pkl)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_val,cls.predict(x_val))
# Out:
# array([[1180,  105],
#        [ 140, 1219]], dtype=int64)

# %%
import pickle

# save the model to disk
filename = 'cls_numCardLength_model.pkl'
pickle.dump(cls, open(filename, 'wb'))

# load the model from disk
cls = pickle.load(open(filename, 'rb'))
cls
# Out:
# RandomForestClassifier(max_depth=14, n_estimators=300, random_state=0)

# %%
pd.qcut(train['city_pop'], 7)
# Out:
# 0               (344.0, 895.0]
# 1          (14871.0, 111772.0]
# 2              (22.999, 344.0]
# 3        (111772.0, 2906700.0]
# 4          (14871.0, 111772.0]
#                  ...
# 15007    (111772.0, 2906700.0]
# 15008          (22.999, 344.0]
# 15009           (344.0, 895.0]
# 15010          (22.999, 344.0]
# 15011           (344.0, 895.0]
# Name: city_pop, Length: 13218, dtype: category
# Categories (7, interval[float64]): [(22.999, 344.0] < (344.0, 895.0] < (895.0, 1841.0] < (1841.0, 4508.0] < (4508.0, 14871.0] < (14871.0, 111772.0] < (111772.0, 2906700.0]]

# %% [markdown]
# Je reprend ce découpage par intervalle que je nomme labels=[]) et essayons d'observer si un label a plus de chance de survie que d'autres

# %%
#classer les ages dans catégories
train["city_pop"] = train["city_pop"]

bins = [0, 22, 346, 911, 4000,  1923, 4542,14783, np.inf]
print(bins)
labels = ['22', '346', '911', '4000', '1923', '4542', '14783','2906700']
train['city_popGroup'] = pd.cut(train['city_pop'], bins, labels =labels)

#draw a bar plot of Age vs. survival
sns.barplot(x="city_popGroup", y="is_fraud", data=train)
plt.show()
# Out:
# [0, 22, 346, 911, 4000, 1923, 4542, 14783, inf]
# <ipython-input-239-45f143092664>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["city_pop"] = train["city_pop"]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-239-45f143092664> in <module>
#       5 print(bins)
#       6 labels = ['22', '346', '911', '4000', '1923', '4542', '14783','2906700']
# ----> 7 train['city_popGroup'] = pd.cut(train['city_pop'], bins, labels =labels)
#       8
#       9 #draw a bar plot of Age vs. survival
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     253         # GH 26045: cast to float64 to avoid an overflow
#     254         if (np.diff(bins.astype("float64")) < 0).any():
# --> 255             raise ValueError("bins must increase monotonically.")
#     256
#     257     fac, bins = _bins_to_cuts(
#
# ValueError: bins must increase monotonically.
